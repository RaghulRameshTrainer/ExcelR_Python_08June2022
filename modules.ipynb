# %% [markdown]
# # OS

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\RaghulRamesh\\Excelr_Python_June2022'

# %%
os.chdir(r'C:\Users\RaghulRamesh\OneDrive\Documents\data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\RaghulRamesh\\OneDrive\\Documents\\data'

# %%
os.mkdir('ExcelR')

# %%
os.rmdir('ExcelR')

# %%
os.makedirs('ExcelR\DataAnalytics\Python\Tueday')

# %%
os.removedirs('ExcelR\DataAnalytics\Python\Tueday')

# %%
os.listdir(os.getcwd())
# Out:
# ['employee.csv', 'sample.json']

# %%
for (root,dirs,files) in os.walk(r'C:\Users\RaghulRamesh\Downloads',topdown=True):
    print(root)
    print(dirs)
    print(files)
    print('----------------------------')
# Out:
# C:\Users\RaghulRamesh\Downloads
# ['Apache Spark solution Folder-20220509T071802Z-001', 'Capgemini_2022Apr-main', 'CG_Python_2022June-main', 'CG_Python_2022June-main (2)', 'CG_Python_2022June-main (3)', 'chromedriver_win32', 'cmder', 'E-Payment-Letter', 'edgedriver_win64', 'Ericsson', 'EricssonMay2022-main', 'EricssonMay2022-main (1)', 'example-flask-crud-master', 'Excelr_MySQL26AprBatch2-main', 'ExcelR_MySQL_April2022-main', 'ExcelR_Python_08June2022-main', 'ExcelR_Python_08June2022-main (1)', 'Excercises', 'flask-crud-master', 'FLUME_DOCS', 'Mini_Proj1', 'My Sql Material-20220505T030730Z-001', 'pdf2doc', 'PIG', 'PPT (1)', 'python-3.8.7-embed-amd64', 'Python_18May-main', 'Spark_CentOS_7_Mar_10_2022', 'Streaming_Progs', 'Tableau Material-20220505T091509Z-001', 'Test']
# ...

# %%
open('ecerlR_python.txt','w').close()

# %%
os.rename('ecerlR_python.txt','excelR_DA.txt')

# %%
os.remove(r'excelR_DA.txt')

# %%
open('ecerlR_python.txt','w').close()

# %%
import shutil

# %%
shutil.copy('ecerlR_python.txt','ecerlR_python_copy.txt')
# Out:
# 'ecerlR_python_copy.txt'

# %%
os.chmod('ecerlR_python.txt',771)

# %% [markdown]
# # sys

# %%
# used IDLE

# %% [markdown]
# # math

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.sqrt(42794873)
# Out:
# 6541.779039374534

# %%
55*66
# Out:
# 3630

# %%
math.prod([55,66])
# Out:
# 3630

# %%
math.factorial(50)
# Out:
# 30414093201713378043612608166064768844377641568960512000000000000

# %%
math.log2(8)
# Out:
# 3.0

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.log(100,3)
# Out:
# 4.19180654857877

# %%
math.log(100,4)
# Out:
# 3.3219280948873626

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.cos(45)
# Out:
# 0.5253219888177297

# %%
math.tan(45)
# Out:
# 1.6197751905438615

# %%
math.cos(0)
# Out:
# 1.0

# %%
math.cos(90)
# Out:
# -0.4480736161291701

# %%
math.ceil(75.7)
# Out:
# 76

# %%
math.floor(75.7)
# Out:
# 75

# %% [markdown]
# # datetime

# %%
import datetime

# %%
timedelta
date
time
datetime

# %%
dob=datetime.date(1956,1,15)

# %%
dob
# Out:
# datetime.date(1956, 1, 15)

# %%
dob.year
# Out:
# 1956

# %%
dob.month
# Out:
# 1

# %%
dob.day
# Out:
# 15

# %%
tday=datetime.date.today()

# %%
dt=datetime.timedelta(100)

# %%
tday+dt
# Out:
# datetime.date(2025, 3, 17)

# %%
tday-dt
# Out:
# datetime.date(2019, 9, 25)

# %%
tday=datetime.datetime.now()

# %%
tday
# Out:
# datetime.datetime(2022, 6, 21, 8, 39, 17, 171516)

# %%
tday.strftime("%a")
# Out:
# 'Tue'

# %%
tday.strftime("%A")
# Out:
# 'Tuesday'

# %%
tday.strftime("%w")
# Out:
# '2'

# %%
tday.strftime("%d")
# Out:
# '21'

# %%
tday.strftime("%m")
# Out:
# '06'

# %%
tday.strftime("%b")
# Out:
# 'Jun'

# %%
tday.strftime("%B")
# Out:
# 'June'

# %%
tday.strftime("%y")
# Out:
# '22'

# %%
tday.strftime("%Y")
# Out:
# '2022'

# %%
tday.strftime("%H")
# Out:
# '08'

# %%
tday.strftime("%M")
# Out:
# '39'

# %%
tday.strftime("%S")
# Out:
# '17'

# %%
tday.strftime("%I")
# Out:
# '08'

# %%
tday.strftime("%I %p")
# Out:
# '08 AM'

# %%
datetime.datetime.now().strftime("%d-%m-%Y %H:%M  %A %B")
# Out:
# '21-06-2022 08:45  Tuesday June'

# %%
datetime.datetime.now().strftime("%m/%d/%Y %I:%M %p")
# Out:
# '06/21/2022 08:46 AM'
